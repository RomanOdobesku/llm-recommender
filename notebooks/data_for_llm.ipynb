# %%
from collections import Counter

import numpy as np
import pandas as pd

pd.set_option("display.max_rows", 50)

# %%
# Load the CSV file
file_path = "../data/category_triplets_12_12.csv"  # Replace with your CSV file path
df = pd.read_csv(file_path)

# Group by predicted_category and sum the counts
popularity_df = df.groupby("predicted_category", as_index=False)["count"].sum()

# Sort by count in descending order
popularity_df = popularity_df.sort_values(by="count", ascending=False)

# Display the sorted DataFrame
popularity_df

# # Optional: Save the result to a new CSV file
# popularity_df.to_csv('predicted_category_popularity.csv', index=False)
# Out:
#                 predicted_category  count
# 7                 Автомобили новые     10
# 93                        Мужчинам     10
# 175                  Уход за телом      9
# 45                        Женщинам      9
# 49   Запчасти для игровых консолей      7
# ..                             ...    ...
# 135         Религиозная атрибутика      1
# 166      Туризм и отдых на природе      1
# 158           Техника для общепита      1
# 160             Товары для гигиены      1
# 184       Чертежные принадлежности      1
#
# [190 rows x 2 columns]

# %%
popularity_df.describe()
# Out:
#             count
# count  190.000000
# mean     3.131579
# std      1.778339
# min      1.000000
# 25%      2.000000
# 50%      3.000000
# 75%      4.000000
# max     10.000000

# %%
def merge_item_cat2(
    interactions_df: pd.DataFrame,
    items_path: str,
) -> pd.DataFrame:
    """
    Merge items from interactions_df with their item_id from items file.
    """
    # Load data
    items_df = pd.read_csv(items_path, sep=",")

    # Ensure 'cat2' is mapped from items.csv where missing
    interactions_df = interactions_df.merge(
        items_df[["item_id", "cat2"]],
        on="item_id",
        how="left",
        suffixes=("", "_from_items"),
    )

    # Fill missing 'cat2' from items.csv
    if "cat2_from_items" in interactions_df.columns:
        interactions_df["cat2"] = interactions_df["cat2"].combine_first(
            interactions_df["cat2_from_items"]
        )
        interactions_df.drop(columns=["cat2_from_items"], inplace=True, errors="ignore")

    return interactions_df

# %%
interactions_df = pd.read_csv(
    "/home/temochka2005/Documents/VScodeProjects/TbankSirius/projectrep/llm-recommender/data/interactions.csv",
    sep=",",
)

# %%
interactions_df
# Out:
#                             time    user_id  item_id  interaction
# 0     2024-12-10 12:25:29.446542  621459934       10            1
# 1     2024-12-10 12:25:31.183529  621459934        6            0
# 2     2024-12-10 12:25:33.161214  621459934        8            1
# 3     2024-12-10 12:25:35.448148  621459934        3            0
# 4     2024-12-10 12:25:37.159775  621459934       10            1
# ...                          ...        ...      ...          ...
# 4797  2024-12-12 16:00:30.466687  856344631     8416            0
# 4798  2024-12-12 16:00:36.817395  856344631     9633            0
# 4799  2024-12-12 16:00:40.881110  856344631    12316            1
# 4800  2024-12-12 16:00:44.190370  856344631     2971            0
# 4801  2024-12-12 16:00:48.876947  856344631     1978            1
#
# [4802 rows x 4 columns]

# %%
interactions_df = merge_item_cat2(
    interactions_df,
    "../data/items.csv",
)

# %%
interactions_df
# Out:
#                             time    user_id  item_id  interaction  \
# 0     2024-12-10 12:25:29.446542  621459934       10            1
# 1     2024-12-10 12:25:31.183529  621459934        6            0
# 2     2024-12-10 12:25:33.161214  621459934        8            1
# 3     2024-12-10 12:25:35.448148  621459934        3            0
# 4     2024-12-10 12:25:37.159775  621459934       10            1
# ...                          ...        ...      ...          ...
# 4797  2024-12-12 16:00:30.466687  856344631     8416            0
# 4798  2024-12-12 16:00:36.817395  856344631     9633            0
# 4799  2024-12-12 16:00:40.881110  856344631    12316            1
# 4800  2024-12-12 16:00:44.190370  856344631     2971            0
# 4801  2024-12-12 16:00:48.876947  856344631     1978            1
#
#                             cat2
# 0               Уход за волосами
# 1               Уход за волосами
# 2               Уход за волосами
# 3               Уход за волосами
# 4               Уход за волосами
# ...                          ...
# 4797  Инструменты и оборудование
# 4798                    Сувениры
# 4799      Товары для бань и саун
# 4800                    Женщинам
# 4801            Парафармацевтика
#
# [4802 rows x 5 columns]

# %%
o = interactions_df.groupby(["cat2"])["interaction"].agg(["count", "mean"])
o1 = interactions_df.groupby(["user_id", "cat2"])["interaction"].agg(["count", "mean"])

cat2_likerate = o.sort_values(by=["count"], ascending=False)

# %%
cat2_likerate
# Out:
#                                            count      mean
# cat2
# Детям                                         63  0.365079
# Женщинам                                      59  0.406780
# Мужчинам                                      49  0.571429
# Охранные системы и видеонаблюдение            39  0.589744
# Виниловые пластинки                           37  0.540541
# ...                                          ...       ...
# Бескаркасная мебель                           13  0.538462
# Бумажная продукция                            13  0.461538
# Техника для дома                              13  0.769231
# Фото и видеокамеры                            13  0.384615
# Мебель и оборудование для салонов красоты     11  0.636364
#
# [219 rows x 2 columns]

# %%
cat2_likerate = cat2_likerate.rename(columns={"mean": "like_rate"})

# %%
sorted_cat2 = cat2_likerate[cat2_likerate["like_rate"] >= 0.6]
sorted_cat2.sort_values(by=["like_rate", "count"], ascending=False)
# Out:
#                                            count  like_rate
# cat2
# Электронные сертификаты                       18   0.833333
# Автомобили новые                              27   0.814815
# Рули и педали                                 16   0.812500
# Mobile gaming                                 15   0.800000
# Компьютеры и периферия                        19   0.789474
# Техника для дома                              13   0.769231
# Личная гигиена                                17   0.764706
# Уход за телом                                 18   0.722222
# Товары для школы и обучения                   18   0.722222
# Техника для кухни                             18   0.722222
# Облачные хранилища                            18   0.722222
# Ретро-консоли                                 21   0.714286
# Детское питание                               14   0.714286
# Игровые приставки и ноутбуки                  24   0.708333
# Nintendo                                      24   0.708333
# Климатическая техника                         17   0.705882
# Компьютерная и офисная мебель                 17   0.705882
# Игровые наушники                              20   0.700000
# Витамины и БАДы                               20   0.700000
# Демонстрационные доски                        23   0.695652
# Туризм и отдых на природе                     16   0.687500
# Ортопедия                                     16   0.687500
# Игровые приставки                             22   0.681818
# Посуда и кухонные принадлежности              22   0.681818
# Аккумуляторы и зарядки                        25   0.680000
# PC                                            25   0.680000
# Текстиль                                      24   0.666667
# Загар и защита от солнца                      18   0.666667
# Видео                                         18   0.666667
# Мебель для спальни и комплектующие            20   0.650000
# Ноутбуки, планшеты и электронные книги        17   0.647059
# Геймпады                                      14   0.642857
# Очки виртуальной реальности                   25   0.640000
# Мебель и оборудование для салонов красоты     11   0.636364
# Кольца                                        19   0.631579
# Мягкая мебель                                 27   0.629630
# Аппаратная косметология и массаж              24   0.625000
# Техника для красоты и здоровья                24   0.625000
# Бизнес-литература                             16   0.625000
# PlayStation                                   21   0.619048
# Наушники и аудиотехника                       21   0.619048
# Товары для бань и саун                        18   0.611111
# Xbox                                          23   0.608696
# Уход за одеждой                               23   0.608696
# Умный дом                                     23   0.608696
# Сувениры                                      28   0.607143
# Игровые жанры                                 30   0.600000
# Блокноты и ежедневники                        25   0.600000
# Аксессуары для электроники                    20   0.600000
# Транспортные средства                         15   0.600000

# %%
sorted_cat2["normalized_like_rate"] = (
    sorted_cat2["like_rate"] / sorted_cat2["like_rate"].sum()
)
sorted_cat2.sort_values(by=["like_rate", "count"], ascending=False)
# Out:
# /tmp/ipykernel_90313/620331154.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sorted_cat2["normalized_like_rate"] = sorted_cat2["like_rate"] / sorted_cat2["like_rate"].sum()
#                                            count  like_rate  \
# cat2
# Электронные сертификаты                       18   0.833333
# Автомобили новые                              27   0.814815
# Рули и педали                                 16   0.812500
# Mobile gaming                                 15   0.800000
# Компьютеры и периферия                        19   0.789474
# Техника для дома                              13   0.769231
# Личная гигиена                                17   0.764706
# Уход за телом                                 18   0.722222
# Товары для школы и обучения                   18   0.722222
# Техника для кухни                             18   0.722222
# Облачные хранилища                            18   0.722222
# Ретро-консоли                                 21   0.714286
# Детское питание                               14   0.714286
# Игровые приставки и ноутбуки                  24   0.708333
# Nintendo                                      24   0.708333
# Климатическая техника                         17   0.705882
# Компьютерная и офисная мебель                 17   0.705882
# Игровые наушники                              20   0.700000
# Витамины и БАДы                               20   0.700000
# Демонстрационные доски                        23   0.695652
# Туризм и отдых на природе                     16   0.687500
# Ортопедия                                     16   0.687500
# Игровые приставки                             22   0.681818
# Посуда и кухонные принадлежности              22   0.681818
# Аккумуляторы и зарядки                        25   0.680000
# PC                                            25   0.680000
# Текстиль                                      24   0.666667
# Загар и защита от солнца                      18   0.666667
# Видео                                         18   0.666667
# Мебель для спальни и комплектующие            20   0.650000
# Ноутбуки, планшеты и электронные книги        17   0.647059
# Геймпады                                      14   0.642857
# Очки виртуальной реальности                   25   0.640000
# Мебель и оборудование для салонов красоты     11   0.636364
# Кольца                                        19   0.631579
# Мягкая мебель                                 27   0.629630
# Аппаратная косметология и массаж              24   0.625000
# Техника для красоты и здоровья                24   0.625000
# Бизнес-литература                             16   0.625000
# PlayStation                                   21   0.619048
# Наушники и аудиотехника                       21   0.619048
# Товары для бань и саун                        18   0.611111
# Xbox                                          23   0.608696
# Уход за одеждой                               23   0.608696
# Умный дом                                     23   0.608696
# Сувениры                                      28   0.607143
# Игровые жанры                                 30   0.600000
# Блокноты и ежедневники                        25   0.600000
# Аксессуары для электроники                    20   0.600000
# Транспортные средства                         15   0.600000
#
#                                            normalized_like_rate
# cat2
# Электронные сертификаты                                0.024539
# Автомобили новые                                       0.023994
# Рули и педали                                          0.023926
# Mobile gaming                                          0.023558
# Компьютеры и периферия                                 0.023248
# Техника для дома                                       0.022652
# Личная гигиена                                         0.022518
# Уход за телом                                          0.021267
# Товары для школы и обучения                            0.021267
# Техника для кухни                                      0.021267
# Облачные хранилища                                     0.021267
# Ретро-консоли                                          0.021034
# Детское питание                                        0.021034
# Игровые приставки и ноутбуки                           0.020858
# Nintendo                                               0.020858
# Климатическая техника                                  0.020786
# Компьютерная и офисная мебель                          0.020786
# Игровые наушники                                       0.020613
# Витамины и БАДы                                        0.020613
# Демонстрационные доски                                 0.020485
# Туризм и отдых на природе                              0.020245
# Ортопедия                                              0.020245
# Игровые приставки                                      0.020078
# Посуда и кухонные принадлежности                       0.020078
# Аккумуляторы и зарядки                                 0.020024
# PC                                                     0.020024
# Текстиль                                               0.019631
# Загар и защита от солнца                               0.019631
# Видео                                                  0.019631
# Мебель для спальни и комплектующие                     0.019141
# Ноутбуки, планшеты и электронные книги                 0.019054
# Геймпады                                               0.018930
# Очки виртуальной реальности                            0.018846
# Мебель и оборудование для салонов красоты              0.018739
# Кольца                                                 0.018598
# Мягкая мебель                                          0.018541
# Аппаратная косметология и массаж                       0.018404
# Техника для красоты и здоровья                         0.018404
# Бизнес-литература                                      0.018404
# PlayStation                                            0.018229
# Наушники и аудиотехника                                0.018229
# Товары для бань и саун                                 0.017995
# Xbox                                                   0.017924
# Уход за одеждой                                        0.017924
# Умный дом                                              0.017924
# Сувениры                                               0.017879
# Игровые жанры                                          0.017668
# Блокноты и ежедневники                                 0.017668
# Аксессуары для электроники                             0.017668
# Транспортные средства                                  0.017668

# %%
sorted_cat2["normalized_like_rate"].sum()
# Out:
# np.float64(1.0000000000000002)

# %%
sorted_cat2.describe()
# Out:
#            count  like_rate  normalized_like_rate
# count  50.000000  50.000000             50.000000
# mean   20.140000   0.679183              0.020000
# std     4.223404   0.062925              0.001853
# min    11.000000   0.600000              0.017668
# 25%    17.000000   0.625000              0.018404
# 50%    20.000000   0.680000              0.020024
# 75%    23.750000   0.712798              0.020990
# max    30.000000   0.833333              0.024539

# %%
def generate_triplets(
    interactions_path,
    items_path,
    start_date=None,
    end_date=None,
    min_count=1,
    output_path="category_triplets.csv",
    filtered_categories=None,
):
    """
    Generate triplets of categories with counts, filtered by date range and minimum count.

    :param interactions_path: Path to the interactions CSV file.
    :param items_path: Path to the items CSV file.
    :param start_date: Start date for filtering interactions (inclusive, format: 'YYYY-MM-DD').
    :param end_date: End date for filtering interactions (inclusive, format: 'YYYY-MM-DD').
    :param min_count: Minimum count of triplets to include in the output.
    :param output_path: Path to save the resulting CSV file.
    """
    # Load datasets
    interactions = pd.read_csv(
        interactions_path,
        usecols=["time", "user_id", "item_id", "interaction"],
        sep=",",
    )
    items = pd.read_csv(items_path, usecols=["item_id", "cat2"], sep=",")

    # Map item_id to cat2 category
    items_mapping = items.set_index("item_id")["cat2"]
    interactions["cat2"] = interactions["item_id"].map(items_mapping)
    # Flter by cat2 with like-rate > 0.6
    if filtered_categories is not None:
        interactions = interactions[interactions["cat2"].isin(filtered_categories)]
    # Filter by date range if specified
    if start_date:
        interactions = interactions[interactions["time"] >= start_date]
    if end_date:
        interactions = interactions[interactions["time"] <= end_date]

    # Filter interactions (interaction == 1)
    like_interactions = interactions[interactions["interaction"] == 1].copy()

    # Sort by user_id and time for sequential processing
    like_interactions = like_interactions.sort_values(by=["user_id", "time"])

    # Generate triplets for each user
    triplets = set()
    for user_id, group in like_interactions.groupby("user_id"):
        categories = group["cat2"].dropna().tolist()
        for i in range(len(categories)):
            for j in range(len(categories)):
                for k in range(len(categories)):
                    if len(set([categories[i], categories[j], categories[k]])) == 3:
                        triplets.add(
                            tuple([categories[i], categories[j], categories[k]])
                        )

    # Count occurrences of each triplet
    triplet_counter = Counter(triplets)

    # Create a DataFrame with counts, filtered by min_count
    result_df = pd.DataFrame.from_records(
        (
            (t[0], t[1], t[2], count)
            for t, count in triplet_counter.items()
            if count >= min_count
        ),
        columns=["user_category_1", "user_category_2", "predicted_category", "count"],
    )

    # Filter pairs (user_category_1, user_category_2) with at least 3 distinct predicted_category values
    filtered_df = result_df.groupby(["user_category_1", "user_category_2"]).filter(
        lambda group: group["predicted_category"].nunique() >= 2
    )

    # Sort the filtered DataFrame by count in descending order
    filtered_df = filtered_df.sort_values(by=["user_category_1", "user_category_2"])

    # Save the sorted and filtered triplets with counts to a CSV file
    filtered_df.to_csv(output_path, index=False)

    print(f"Output saved to '{output_path}'.")


# Example usage
generate_triplets(
    interactions_path="../data/interactions.csv",
    items_path="../data/items.csv",
    start_date="2024-12-10",
    end_date="2024-12-13",
    min_count=1,
    output_path="../data/category_triplets_actual_12_12_1111.csv",
    filtered_categories=list(sorted_cat2.index),
)
# Out:
# Output saved to '../data/category_triplets_actual_12_12_1111.csv'.

# %%
import pandas as pd

# Load the CSV file
file_path = (
    "../data/category_triplets_actual_12_12_1111.csv"  # Replace with your CSV file path
)
df = pd.read_csv(file_path)

# Create a canonical pair representation (sorted tuple)
df["canonical_pair"] = df.apply(
    lambda row: tuple(sorted([row["user_category_1"], row["user_category_2"]])), axis=1
)

# Identify duplicates based on canonical_pair and predicted_category
df = df.drop_duplicates(subset=["canonical_pair", "predicted_category"], keep="first")

# Drop the auxiliary column
df = df.drop(columns=["canonical_pair"])

# Save the cleaned DataFrame to a new CSV file
# df.to_csv("../data/cleaned_file_category_triplets.csv", index=False)

# Display the result
print(df)
# Out:
#       user_category_1          user_category_2  \
# 0       Mobile gaming                 Nintendo
# 1       Mobile gaming                 Nintendo
# 2       Mobile gaming                 Nintendo
# 3       Mobile gaming                 Nintendo
# 4       Mobile gaming                 Nintendo
# ...               ...                      ...
# 93641   Уход за телом  Электронные сертификаты
# 93642   Уход за телом  Электронные сертификаты
# 93643   Уход за телом  Электронные сертификаты
# 93644   Уход за телом  Электронные сертификаты
# 93645   Уход за телом  Электронные сертификаты
#
#                            predicted_category  count
# 0                Игровые приставки и ноутбуки      1
# 1            Посуда и кухонные принадлежности      1
# 2                                   Ортопедия      1
# 3                   Туризм и отдых на природе      1
# 4                       Климатическая техника      1
# ...                                       ...    ...
# 93641                             PlayStation      1
# 93642  Ноутбуки, планшеты и электронные книги      1
# 93643                           Ретро-консоли      1
# 93644                           Мягкая мебель      1
# 93645                         Уход за одеждой      1
#
# [47897 rows x 4 columns]

# %%
df["predicted_category"].value_counts()
# Out:
# predicted_category
# Компьютерная и офисная мебель                1122
# Аккумуляторы и зарядки                       1115
# Туризм и отдых на природе                    1104
# Техника для красоты и здоровья               1103
# Автомобили новые                             1102
# Очки виртуальной реальности                  1086
# Климатическая техника                        1080
# Демонстрационные доски                       1078
# Уход за телом                                1075
# Игровые жанры                                1075
# Электронные сертификаты                      1074
# Личная гигиена                               1073
# Игровые наушники                             1072
# Витамины и БАДы                              1066
# Облачные хранилища                           1048
# PlayStation                                  1047
# Ретро-консоли                                1044
# Загар и защита от солнца                     1032
# Игровые приставки                            1030
# Блокноты и ежедневники                       1019
# Техника для кухни                            1018
# PC                                           1013
# Бизнес-литература                            1004
# Ортопедия                                    1003
# Уход за одеждой                               997
# Товары для школы и обучения                   990
# Посуда и кухонные принадлежности              980
# Геймпады                                      976
# Xbox                                          972
# Товары для бань и саун                        971
# Рули и педали                                 930
# Аппаратная косметология и массаж              929
# Наушники и аудиотехника                       929
# Умный дом                                     913
# Мебель для спальни и комплектующие            906
# Аксессуары для электроники                    905
# Nintendo                                      896
# Mobile gaming                                 865
# Техника для дома                              838
# Видео                                         832
# Мягкая мебель                                 831
# Текстиль                                      831
# Транспортные средства                         810
# Компьютеры и периферия                        809
# Кольца                                        808
# Игровые приставки и ноутбуки                  791
# Ноутбуки, планшеты и электронные книги        789
# Сувениры                                      760
# Детское питание                               733
# Мебель и оборудование для салонов красоты     423
# Name: count, dtype: int64

# %%
predicitons_with_likerate = pd.merge(
    df, sorted_cat2, left_on="predicted_category", right_on="cat2", how="left"
)

# %%
sorted_cat2["like_rate_scaled"] = (
    sorted_cat2["like_rate"] - sorted_cat2["like_rate"].min()
) / (sorted_cat2["like_rate"].max() - sorted_cat2["like_rate"].min()) * (1 - 0.2) + 0.2
sorted_cat2
# Out:
# /tmp/ipykernel_90313/2316489414.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sorted_cat2["like_rate_scaled"] = (sorted_cat2["like_rate"] - sorted_cat2["like_rate"].min()) / (
#                                            count  like_rate  \
# cat2
# Игровые жанры                                 30   0.600000
# Сувениры                                      28   0.607143
# Автомобили новые                              27   0.814815
# Мягкая мебель                                 27   0.629630
# Очки виртуальной реальности                   25   0.640000
# Аккумуляторы и зарядки                        25   0.680000
# Блокноты и ежедневники                        25   0.600000
# PC                                            25   0.680000
# Аппаратная косметология и массаж              24   0.625000
# Игровые приставки и ноутбуки                  24   0.708333
# Текстиль                                      24   0.666667
# Nintendo                                      24   0.708333
# Техника для красоты и здоровья                24   0.625000
# Демонстрационные доски                        23   0.695652
# Xbox                                          23   0.608696
# Уход за одеждой                               23   0.608696
# Умный дом                                     23   0.608696
# Игровые приставки                             22   0.681818
# Посуда и кухонные принадлежности              22   0.681818
# PlayStation                                   21   0.619048
# Ретро-консоли                                 21   0.714286
# Наушники и аудиотехника                       21   0.619048
# Мебель для спальни и комплектующие            20   0.650000
# Игровые наушники                              20   0.700000
# Аксессуары для электроники                    20   0.600000
# Витамины и БАДы                               20   0.700000
# Кольца                                        19   0.631579
# Компьютеры и периферия                        19   0.789474
# Электронные сертификаты                       18   0.833333
# Уход за телом                                 18   0.722222
# Товары для школы и обучения                   18   0.722222
# Техника для кухни                             18   0.722222
# Товары для бань и саун                        18   0.611111
# Загар и защита от солнца                      18   0.666667
# Облачные хранилища                            18   0.722222
# Видео                                         18   0.666667
# Климатическая техника                         17   0.705882
# Компьютерная и офисная мебель                 17   0.705882
# Ноутбуки, планшеты и электронные книги        17   0.647059
# Личная гигиена                                17   0.764706
# Туризм и отдых на природе                     16   0.687500
# Рули и педали                                 16   0.812500
# Ортопедия                                     16   0.687500
# Бизнес-литература                             16   0.625000
# Mobile gaming                                 15   0.800000
# Транспортные средства                         15   0.600000
# Геймпады                                      14   0.642857
# Детское питание                               14   0.714286
# Техника для дома                              13   0.769231
# Мебель и оборудование для салонов красоты     11   0.636364
#
#                                            normalized_like_rate  \
# cat2
# Игровые жанры                                          0.017668
# Сувениры                                               0.017879
# Автомобили новые                                       0.023994
# Мягкая мебель                                          0.018541
# Очки виртуальной реальности                            0.018846
# Аккумуляторы и зарядки                                 0.020024
# Блокноты и ежедневники                                 0.017668
# PC                                                     0.020024
# Аппаратная косметология и массаж                       0.018404
# Игровые приставки и ноутбуки                           0.020858
# Текстиль                                               0.019631
# Nintendo                                               0.020858
# Техника для красоты и здоровья                         0.018404
# Демонстрационные доски                                 0.020485
# Xbox                                                   0.017924
# Уход за одеждой                                        0.017924
# Умный дом                                              0.017924
# Игровые приставки                                      0.020078
# Посуда и кухонные принадлежности                       0.020078
# PlayStation                                            0.018229
# Ретро-консоли                                          0.021034
# Наушники и аудиотехника                                0.018229
# Мебель для спальни и комплектующие                     0.019141
# Игровые наушники                                       0.020613
# Аксессуары для электроники                             0.017668
# Витамины и БАДы                                        0.020613
# Кольца                                                 0.018598
# Компьютеры и периферия                                 0.023248
# Электронные сертификаты                                0.024539
# Уход за телом                                          0.021267
# Товары для школы и обучения                            0.021267
# Техника для кухни                                      0.021267
# Товары для бань и саун                                 0.017995
# Загар и защита от солнца                               0.019631
# Облачные хранилища                                     0.021267
# Видео                                                  0.019631
# Климатическая техника                                  0.020786
# Компьютерная и офисная мебель                          0.020786
# Ноутбуки, планшеты и электронные книги                 0.019054
# Личная гигиена                                         0.022518
# Туризм и отдых на природе                              0.020245
# Рули и педали                                          0.023926
# Ортопедия                                              0.020245
# Бизнес-литература                                      0.018404
# Mobile gaming                                          0.023558
# Транспортные средства                                  0.017668
# Геймпады                                               0.018930
# Детское питание                                        0.021034
# Техника для дома                                       0.022652
# Мебель и оборудование для салонов красоты              0.018739
#
#                                            like_rate_scaled
# cat2
# Игровые жанры                                      0.200000
# Сувениры                                           0.224490
# Автомобили новые                                   0.936508
# Мягкая мебель                                      0.301587
# Очки виртуальной реальности                        0.337143
# Аккумуляторы и зарядки                             0.474286
# Блокноты и ежедневники                             0.200000
# PC                                                 0.474286
# Аппаратная косметология и массаж                   0.285714
# Игровые приставки и ноутбуки                       0.571429
# Текстиль                                           0.428571
# Nintendo                                           0.571429
# Техника для красоты и здоровья                     0.285714
# Демонстрационные доски                             0.527950
# Xbox                                               0.229814
# Уход за одеждой                                    0.229814
# Умный дом                                          0.229814
# Игровые приставки                                  0.480519
# Посуда и кухонные принадлежности                   0.480519
# PlayStation                                        0.265306
# Ретро-консоли                                      0.591837
# Наушники и аудиотехника                            0.265306
# Мебель для спальни и комплектующие                 0.371429
# Игровые наушники                                   0.542857
# Аксессуары для электроники                         0.200000
# Витамины и БАДы                                    0.542857
# Кольца                                             0.308271
# Компьютеры и периферия                             0.849624
# Электронные сертификаты                            1.000000
# Уход за телом                                      0.619048
# Товары для школы и обучения                        0.619048
# Техника для кухни                                  0.619048
# Товары для бань и саун                             0.238095
# Загар и защита от солнца                           0.428571
# Облачные хранилища                                 0.619048
# Видео                                              0.428571
# Климатическая техника                              0.563025
# Компьютерная и офисная мебель                      0.563025
# Ноутбуки, планшеты и электронные книги             0.361345
# Личная гигиена                                     0.764706
# Туризм и отдых на природе                          0.500000
# Рули и педали                                      0.928571
# Ортопедия                                          0.500000
# Бизнес-литература                                  0.285714
# Mobile gaming                                      0.885714
# Транспортные средства                              0.200000
# Геймпады                                           0.346939
# Детское питание                                    0.591837
# Техника для дома                                   0.780220
# Мебель и оборудование для салонов красоты          0.324675

# %%
sorted_cat2["normalized_like_rate_scaled"] = (
    sorted_cat2["like_rate_scaled"] / sorted_cat2["like_rate_scaled"].sum()
)
sorted_cat2.sort_values(by=["like_rate", "count"], ascending=False)
# Out:
# /tmp/ipykernel_90313/2638944593.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sorted_cat2["normalized_like_rate_scaled"] = (
#                                            count  like_rate  \
# cat2
# Электронные сертификаты                       18   0.833333
# Автомобили новые                              27   0.814815
# Рули и педали                                 16   0.812500
# Mobile gaming                                 15   0.800000
# Компьютеры и периферия                        19   0.789474
# Техника для дома                              13   0.769231
# Личная гигиена                                17   0.764706
# Уход за телом                                 18   0.722222
# Товары для школы и обучения                   18   0.722222
# Техника для кухни                             18   0.722222
# Облачные хранилища                            18   0.722222
# Ретро-консоли                                 21   0.714286
# Детское питание                               14   0.714286
# Игровые приставки и ноутбуки                  24   0.708333
# Nintendo                                      24   0.708333
# Климатическая техника                         17   0.705882
# Компьютерная и офисная мебель                 17   0.705882
# Игровые наушники                              20   0.700000
# Витамины и БАДы                               20   0.700000
# Демонстрационные доски                        23   0.695652
# Туризм и отдых на природе                     16   0.687500
# Ортопедия                                     16   0.687500
# Игровые приставки                             22   0.681818
# Посуда и кухонные принадлежности              22   0.681818
# Аккумуляторы и зарядки                        25   0.680000
# PC                                            25   0.680000
# Текстиль                                      24   0.666667
# Загар и защита от солнца                      18   0.666667
# Видео                                         18   0.666667
# Мебель для спальни и комплектующие            20   0.650000
# Ноутбуки, планшеты и электронные книги        17   0.647059
# Геймпады                                      14   0.642857
# Очки виртуальной реальности                   25   0.640000
# Мебель и оборудование для салонов красоты     11   0.636364
# Кольца                                        19   0.631579
# Мягкая мебель                                 27   0.629630
# Аппаратная косметология и массаж              24   0.625000
# Техника для красоты и здоровья                24   0.625000
# Бизнес-литература                             16   0.625000
# PlayStation                                   21   0.619048
# Наушники и аудиотехника                       21   0.619048
# Товары для бань и саун                        18   0.611111
# Xbox                                          23   0.608696
# Уход за одеждой                               23   0.608696
# Умный дом                                     23   0.608696
# Сувениры                                      28   0.607143
# Игровые жанры                                 30   0.600000
# Блокноты и ежедневники                        25   0.600000
# Аксессуары для электроники                    20   0.600000
# Транспортные средства                         15   0.600000
#
#                                            normalized_like_rate  \
# cat2
# Электронные сертификаты                                0.024539
# Автомобили новые                                       0.023994
# Рули и педали                                          0.023926
# Mobile gaming                                          0.023558
# Компьютеры и периферия                                 0.023248
# Техника для дома                                       0.022652
# Личная гигиена                                         0.022518
# Уход за телом                                          0.021267
# Товары для школы и обучения                            0.021267
# Техника для кухни                                      0.021267
# Облачные хранилища                                     0.021267
# Ретро-консоли                                          0.021034
# Детское питание                                        0.021034
# Игровые приставки и ноутбуки                           0.020858
# Nintendo                                               0.020858
# Климатическая техника                                  0.020786
# Компьютерная и офисная мебель                          0.020786
# Игровые наушники                                       0.020613
# Витамины и БАДы                                        0.020613
# Демонстрационные доски                                 0.020485
# Туризм и отдых на природе                              0.020245
# Ортопедия                                              0.020245
# Игровые приставки                                      0.020078
# Посуда и кухонные принадлежности                       0.020078
# Аккумуляторы и зарядки                                 0.020024
# PC                                                     0.020024
# Текстиль                                               0.019631
# Загар и защита от солнца                               0.019631
# Видео                                                  0.019631
# Мебель для спальни и комплектующие                     0.019141
# Ноутбуки, планшеты и электронные книги                 0.019054
# Геймпады                                               0.018930
# Очки виртуальной реальности                            0.018846
# Мебель и оборудование для салонов красоты              0.018739
# Кольца                                                 0.018598
# Мягкая мебель                                          0.018541
# Аппаратная косметология и массаж                       0.018404
# Техника для красоты и здоровья                         0.018404
# Бизнес-литература                                      0.018404
# PlayStation                                            0.018229
# Наушники и аудиотехника                                0.018229
# Товары для бань и саун                                 0.017995
# Xbox                                                   0.017924
# Уход за одеждой                                        0.017924
# Умный дом                                              0.017924
# Сувениры                                               0.017879
# Игровые жанры                                          0.017668
# Блокноты и ежедневники                                 0.017668
# Аксессуары для электроники                             0.017668
# Транспортные средства                                  0.017668
#
#                                            like_rate_scaled  \
# cat2
# Электронные сертификаты                            1.000000
# Автомобили новые                                   0.936508
# Рули и педали                                      0.928571
# Mobile gaming                                      0.885714
# Компьютеры и периферия                             0.849624
# Техника для дома                                   0.780220
# Личная гигиена                                     0.764706
# Уход за телом                                      0.619048
# Товары для школы и обучения                        0.619048
# Техника для кухни                                  0.619048
# Облачные хранилища                                 0.619048
# Ретро-консоли                                      0.591837
# Детское питание                                    0.591837
# Игровые приставки и ноутбуки                       0.571429
# Nintendo                                           0.571429
# Климатическая техника                              0.563025
# Компьютерная и офисная мебель                      0.563025
# Игровые наушники                                   0.542857
# Витамины и БАДы                                    0.542857
# Демонстрационные доски                             0.527950
# Туризм и отдых на природе                          0.500000
# Ортопедия                                          0.500000
# Игровые приставки                                  0.480519
# Посуда и кухонные принадлежности                   0.480519
# Аккумуляторы и зарядки                             0.474286
# PC                                                 0.474286
# Текстиль                                           0.428571
# Загар и защита от солнца                           0.428571
# Видео                                              0.428571
# Мебель для спальни и комплектующие                 0.371429
# Ноутбуки, планшеты и электронные книги             0.361345
# Геймпады                                           0.346939
# Очки виртуальной реальности                        0.337143
# Мебель и оборудование для салонов красоты          0.324675
# Кольца                                             0.308271
# Мягкая мебель                                      0.301587
# Аппаратная косметология и массаж                   0.285714
# Техника для красоты и здоровья                     0.285714
# Бизнес-литература                                  0.285714
# PlayStation                                        0.265306
# Наушники и аудиотехника                            0.265306
# Товары для бань и саун                             0.238095
# Xbox                                               0.229814
# Уход за одеждой                                    0.229814
# Умный дом                                          0.229814
# Сувениры                                           0.224490
# Игровые жанры                                      0.200000
# Блокноты и ежедневники                             0.200000
# Аксессуары для электроники                         0.200000
# Транспортные средства                              0.200000
#
#                                            normalized_like_rate_scaled
# cat2
# Электронные сертификаты                                       0.042419
# Автомобили новые                                              0.039726
# Рули и педали                                                 0.039389
# Mobile gaming                                                 0.037571
# Компьютеры и периферия                                        0.036040
# Техника для дома                                              0.033096
# Личная гигиена                                                0.032438
# Уход за телом                                                 0.026259
# Товары для школы и обучения                                   0.026259
# Техника для кухни                                             0.026259
# Облачные хранилища                                            0.026259
# Ретро-консоли                                                 0.025105
# Детское питание                                               0.025105
# Игровые приставки и ноутбуки                                  0.024239
# Nintendo                                                      0.024239
# Климатическая техника                                         0.023883
# Компьютерная и офисная мебель                                 0.023883
# Игровые наушники                                              0.023028
# Витамины и БАДы                                               0.023028
# Демонстрационные доски                                        0.022395
# Туризм и отдых на природе                                     0.021210
# Ортопедия                                                     0.021210
# Игровые приставки                                             0.020383
# Посуда и кухонные принадлежности                              0.020383
# Аккумуляторы и зарядки                                        0.020119
# PC                                                            0.020119
# Текстиль                                                      0.018180
# Загар и защита от солнца                                      0.018180
# Видео                                                         0.018180
# Мебель для спальни и комплектующие                            0.015756
# Ноутбуки, планшеты и электронные книги                        0.015328
# Геймпады                                                      0.014717
# Очки виртуальной реальности                                   0.014301
# Мебель и оборудование для салонов красоты                     0.013772
# Кольца                                                        0.013077
# Мягкая мебель                                                 0.012793
# Аппаратная косметология и массаж                              0.012120
# Техника для красоты и здоровья                                0.012120
# Бизнес-литература                                             0.012120
# PlayStation                                                   0.011254
# Наушники и аудиотехника                                       0.011254
# Товары для бань и саун                                        0.010100
# Xbox                                                          0.009748
# Уход за одеждой                                               0.009748
# Умный дом                                                     0.009748
# Сувениры                                                      0.009523
# Игровые жанры                                                 0.008484
# Блокноты и ежедневники                                        0.008484
# Аксессуары для электроники                                    0.008484
# Транспортные средства                                         0.008484

# %%
# from tqdm import tqdm

random_choice = np.random.choice(
    sorted_cat2.index, p=sorted_cat2["normalized_like_rate_scaled"], size=75 * 1000
)

category_triplets = pd.read_csv(
    "../data/category_triplets_actual_12_12_1111.csv", sep=","
)


# Подсчёт уникальных элементов и их количества
unique_elements, counts = np.unique(random_choice, return_counts=True)

random_choice_df = pd.DataFrame(
    {"predicted_category": unique_elements, "counts": counts}
)

sampling_df = pd.DataFrame()


for cat, count in zip(unique_elements, counts):
    # Выбираем строки из category_triplets для текущей категории
    matching_rows = category_triplets[category_triplets["predicted_category"] == cat]

    sampled_rows = matching_rows.sample(n=count, replace=True)

    sampling_df = pd.concat([sampling_df, sampled_rows], ignore_index=True)


# Вывод результата
for element, count in zip(unique_elements, counts):
    print(f"Элемент {element} встречается {count} раз(а)")
sampling_df
# Out:
# Элемент Mobile gaming встречается 2833 раз(а)
# Элемент Nintendo встречается 1878 раз(а)
# Элемент PC встречается 1447 раз(а)
# Элемент PlayStation встречается 855 раз(а)
# Элемент Xbox встречается 761 раз(а)
# Элемент Автомобили новые встречается 2958 раз(а)
# Элемент Аккумуляторы и зарядки встречается 1532 раз(а)
# Элемент Аксессуары для электроники встречается 619 раз(а)
# Элемент Аппаратная косметология и массаж встречается 958 раз(а)
# Элемент Бизнес-литература встречается 933 раз(а)
# Элемент Блокноты и ежедневники встречается 652 раз(а)
# Элемент Видео встречается 1442 раз(а)
# Элемент Витамины и БАДы встречается 1681 раз(а)
# Элемент Геймпады встречается 1087 раз(а)
# Элемент Демонстрационные доски встречается 1721 раз(а)
# Элемент Детское питание встречается 1834 раз(а)
# Элемент Загар и защита от солнца встречается 1379 раз(а)
# Элемент Игровые жанры встречается 677 раз(а)
# Элемент Игровые наушники встречается 1772 раз(а)
# Элемент Игровые приставки встречается 1516 раз(а)
# Элемент Игровые приставки и ноутбуки встречается 1795 раз(а)
# Элемент Климатическая техника встречается 1726 раз(а)
# Элемент Кольца встречается 1030 раз(а)
# Элемент Компьютерная и офисная мебель встречается 1773 раз(а)
# Элемент Компьютеры и периферия встречается 2680 раз(а)
# Элемент Личная гигиена встречается 2447 раз(а)
# Элемент Мебель для спальни и комплектующие встречается 1196 раз(а)
# Элемент Мебель и оборудование для салонов красоты встречается 1049 раз(а)
# Элемент Мягкая мебель встречается 970 раз(а)
# Элемент Наушники и аудиотехника встречается 822 раз(а)
# Элемент Ноутбуки, планшеты и электронные книги встречается 1085 раз(а)
# Элемент Облачные хранилища встречается 1995 раз(а)
# Элемент Ортопедия встречается 1605 раз(а)
# Элемент Очки виртуальной реальности встречается 1049 раз(а)
# Элемент Посуда и кухонные принадлежности встречается 1513 раз(а)
# Элемент Ретро-консоли встречается 1881 раз(а)
# Элемент Рули и педали встречается 2962 раз(а)
# Элемент Сувениры встречается 679 раз(а)
# Элемент Текстиль встречается 1319 раз(а)
# Элемент Техника для дома встречается 2436 раз(а)
# Элемент Техника для красоты и здоровья встречается 868 раз(а)
# Элемент Техника для кухни встречается 1891 раз(а)
# Элемент Товары для бань и саун встречается 787 раз(а)
# Элемент Товары для школы и обучения встречается 2050 раз(а)
# Элемент Транспортные средства встречается 651 раз(а)
# Элемент Туризм и отдых на природе встречается 1555 раз(а)
# Элемент Умный дом встречается 733 раз(а)
# Элемент Уход за одеждой встречается 761 раз(а)
# Элемент Уход за телом встречается 1975 раз(а)
# Элемент Электронные сертификаты встречается 3182 раз(а)
#                               user_category_1              user_category_2  \
# 0      Ноутбуки, планшеты и электронные книги                    Ортопедия
# 1                           Игровые приставки       Демонстрационные доски
# 2            Аппаратная косметология и массаж       Аккумуляторы и зарядки
# 3                              Личная гигиена    Туризм и отдых на природе
# 4                           Игровые приставки      Наушники и аудиотехника
# ...                                       ...                          ...
# 74995                  Компьютеры и периферия                        Видео
# 74996                   Транспортные средства       Блокноты и ежедневники
# 74997                                Текстиль  Товары для школы и обучения
# 74998                           Уход за телом       Компьютеры и периферия
# 74999                                Текстиль                Mobile gaming
#
#             predicted_category  count
# 0                Mobile gaming      1
# 1                Mobile gaming      1
# 2                Mobile gaming      1
# 3                Mobile gaming      1
# 4                Mobile gaming      1
# ...                        ...    ...
# 74995  Электронные сертификаты      1
# 74996  Электронные сертификаты      1
# 74997  Электронные сертификаты      1
# 74998  Электронные сертификаты      1
# 74999  Электронные сертификаты      1
#
# [75000 rows x 4 columns]

# %%
sampling_df[sampling_df["predicted_category"] == "Mobile gaming"]
# Out:
#                              user_category_1            user_category_2  \
# 0     Ноутбуки, планшеты и электронные книги                  Ортопедия
# 1                          Игровые приставки     Демонстрационные доски
# 2           Аппаратная косметология и массаж     Аккумуляторы и зарядки
# 3                             Личная гигиена  Туризм и отдых на природе
# 4                          Игровые приставки    Наушники и аудиотехника
# ...                                      ...                        ...
# 2828                        Автомобили новые            Уход за одеждой
# 2829                 Наушники и аудиотехника              Рули и педали
# 2830                           Ретро-консоли                         PC
# 2831                   Транспортные средства                   Nintendo
# 2832                          Личная гигиена              Ретро-консоли
#
#      predicted_category  count
# 0         Mobile gaming      1
# 1         Mobile gaming      1
# 2         Mobile gaming      1
# 3         Mobile gaming      1
# 4         Mobile gaming      1
# ...                 ...    ...
# 2828      Mobile gaming      1
# 2829      Mobile gaming      1
# 2830      Mobile gaming      1
# 2831      Mobile gaming      1
# 2832      Mobile gaming      1
#
# [2833 rows x 4 columns]

# %%
sampling_df.to_csv("../data/sampled_triplets_best.csv", index=False)
